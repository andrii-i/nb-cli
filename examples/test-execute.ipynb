# %%
print('Hello from Jupyter CLI\!')
# Out:
# Hello from Jupyter CLI\!
# <>:1: SyntaxWarning: invalid escape sequence '\!'
# <>:1: SyntaxWarning: invalid escape sequence '\!'
# /var/folders/zz/mkx8_cg176xdvqx28gqt05wr0000gr/T/ipykernel_13703/1161329743.py:1: SyntaxWarning: invalid escape sequence '\!'
#   print('Hello from Jupyter CLI\!')

# %%
x = 42
print(f'The answer is {x}')
# Out:
# The answer is 42

# %%
1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 1/0
#
# ZeroDivisionError: division by zero
